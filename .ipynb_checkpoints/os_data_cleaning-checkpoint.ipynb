# %%
import os
import shutil
import pandas as pd

target_dir = '/media/chansik/Samsung_T5/mets_stripped'

map_dict = {'original_MRN': [],
            'coded_ID': []}

for idx, directory in enumerate(os.listdir(target_dir)):
    new_directory = 'M' + str(idx + 10001)[1:]
    
    map_dict['original_MRN'].append(directory)
    map_dict['coded_ID'].append(new_directory)
    
    shutil.move(os.path.join(target_dir, directory),
                os.path.join(target_dir, new_directory))
    
result_df = pd.DataFrame.from_dict(map_dict)
result_df.to_csv(os.path.join('/media/chansik/Samsung_T5', 'PYW_mets_mapping.csv'), index=False)

# %%
import os
import shutil
import pandas as pd

working_dir = '/media/chansik/Samsung_T5/GBMsurv_PCJ'
gbm_list = pd.read_csv('GBM_list.csv')
gbm_list = list(gbm_list['GBM'].astype('str'))

not_included = []

for mrn in gbm_list:
    if mrn not in os.listdir(working_dir):
        not_included.append(mrn)
        continue
    
    pt_dir_path = os.path.join(working_dir, mrn)
    
    for series in os.listdir(pt_dir_path):
        if series.split('_', 1)[1] in ['T2F', 'flair', 'FLAIR_post']: 
            series_path = os.path.join(pt_dir_path, series)
            shutil.copy(series_path)
            
    
#print(not_included)
# Out:
# /media/chansik/Samsung_T5/GBMsurv_PCJ/2411800/2411800_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/4309782/4309782_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8107519/8107519_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/5519078/5519078_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7857692/7857692_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8219381/8219381_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8318465/8318465_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8206601/8206601_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8001370/8001370_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8290191/8290191_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7886931/7886931_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/1184532/1184532_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7870422/7870422_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8127365/8127365_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7975211/7975211_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8206586/8206586_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8020645/8020645_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8250445/8250445_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/3057017/3057017_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/6587279/6587279_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8015074/8015074_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/3802496/3802496_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8303769/8303769_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8297121/8297121_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8190646/8190646_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/5878710/5878710_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8238561/8238561_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7936348/7936348_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8232694/8232694_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7996266/7996266_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8145726/8145726_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7970660/7970660_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8122922/8122922_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/3929225/3929225_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7910990/7910990_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8184994/8184994_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8054247/8054247_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/5121900/5121900_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7921710/7921710_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8214284/8214284_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8109230/8109230_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7424786/7424786_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/3944287/3944287_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/5321826/5321826_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8362968/8362968_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7816355/7816355_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8181344/8181344_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8194446/8194446_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7862897/7862897_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8267140/8267140_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8321636/8321636_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8236180/8236180_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8114173/8114173_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8296920/8296920_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8051073/8051073_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8008701/8008701_FLAIR_post
# /media/chansik/Samsung_T5/GBMsurv_PCJ/1012729/1012729_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8182837/8182837_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/5987114/5987114_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8069844/8069844_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/3705433/3705433_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7798641/7798641_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/1100120/1100120_flair
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8087763/8087763_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8343533/8343533_FLAIR_post
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7945123/7945123_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8365682/8365682_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/2293908/2293908_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7875923/7875923_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7797494/7797494_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/5722361/5722361_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8023836/8023836_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8151798/8151798_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/7985046/7985046_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8106159/8106159_T2F
# /media/chansik/Samsung_T5/GBMsurv_PCJ/8103623/8103623_T2F
